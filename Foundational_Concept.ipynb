# %%
print("Hello, My name is Anas Khan and my hobbies is to play video games.")
# Out:
# Hello, My name is Anas Khan and my hobbies is to play video games.

# %%
# This is a comment

# %%
a = int(1)
print(type(a))
b = float(1)
print(type(b))
c = str(1)
print(type(c))
d = bool(False)
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
int(b)
# Out:
# 1

# %%
int(c)
# Out:
# 1

# %%
int(d)
# Out:
# 0

# %%
a = 5
b = 10


print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 15
# -5
# 50
# 0.5

# %%
minutes = 160
hours = minutes / 60 

print("Hours in 160 minutes:", hours)
# Out:
# Hours in 160 minutes: 2.6666666666666665
