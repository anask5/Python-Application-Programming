# %%
my_list = []
print(type(my_list))
# Out:
# <class 'list'>

# %%
shopping_item = ["Watch", "laptop", "shoes", "pen", "clothes"]
print(shopping_item)
# Out:
# ['Watch', 'laptop', 'shoes', 'pen', 'clothes']

# %%
shopping_item.append("Football")
print(shopping_item)
# Out:
# ['Watch', 'laptop', 'shoes', 'pen', 'clothes', 'Football']

# %%
print(shopping_item[-1])
# Out:
# Football

# %%
print(shopping_item)
print(shopping_item[1], shopping_item[2])
# Out:
# ['Watch', 'laptop', 'shoes', 'pen', 'clothes', 'Football']
# laptop shoes

# %%
shopping_item[3]="Notebook"

# %%
shopping_item.remove("clothes")
print("Final shopping list:", shopping_item)
# Out:
# Final shopping list: ['Watch', 'laptop', 'shoes', 'Notebook', 'Football']
